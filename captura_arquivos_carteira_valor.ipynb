# %%
from datetime import datetime
from datetime import timedelta
from datetime import date
import datetime
import calendar
import time
import os
import getpass
from datetime import date, timedelta
from pathlib import Path
import shutil

from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support.ui import WebDriverWait
from selenium.common.exceptions import TimeoutException
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

from dotenv import load_dotenv
from dotenv import find_dotenv
load_dotenv(find_dotenv())


def get_webdriver(download_path = 'downloads'):
    basedir = os.path.abspath('.')
    download_path = os.path.join(basedir, download_path)

    options = Options()
    options.add_argument('--profile-directory=Default')

    options.add_experimental_option("prefs", {
        "download.default_directory": download_path,
        "download.prompt_for_download": False,
        "download.directory_upgrade": True,
        "safebrowsing.enabled": True
    })

    driver = webdriver.Chrome(
        executable_path='chromedriver.exe',
        options=options
    )

    # maximiza o browser
    #driver.maximize_window()    

    return driver

# %%
webdriver = get_webdriver()

# %%
for ano in range(2012, 2021):
    for mes in range (1,13):
        url = f'https://www.valor.com.br/carteira-valor-iframe/historico/{mes}/{ano}'

        if ano == 2020 and mes == 8:
            url = 'https://www.valor.com.br/carteira-valor-iframe/'

        if ano == 2020 and mes > 8:
            break

        print(url)
        webdriver.get(url)
        html = webdriver.page_source.encode('utf-8')
        file_name = f'{ano}_{mes}_carteira_valor.html'
        file_path = os.path.join('htmls', file_name)
        print(file_name)
        with open(file_path, 'wb') as fid:
            print('salvando arquivo...')
            fid.write(html)
# Out:
# https://www.valor.com.br/carteira-valor-iframe/historico/1/2012
# 2012_1_carteira_valor.html
# salvando arquivo...
# https://www.valor.com.br/carteira-valor-iframe/historico/2/2012
# 2012_2_carteira_valor.html
# salvando arquivo...
# https://www.valor.com.br/carteira-valor-iframe/historico/3/2012
# 2012_3_carteira_valor.html
# salvando arquivo...
# https://www.valor.com.br/carteira-valor-iframe/historico/4/2012
# 2012_4_carteira_valor.html
# salvando arquivo...
# https://www.valor.com.br/carteira-valor-iframe/historico/5/2012
# 2012_5_carteira_valor.html
# salvando arquivo...
# https://www.valor.com.br/carteira-valor-iframe/historico/6/2012
# 2012_6_carteira_valor.html
# salvando arquivo...
# https://www.valor.com.br/carteira-valor-iframe/historico/7/2012
# 2012_7_carteira_valor.html
# salvando arquivo...
# https://www.valor.com.br/carteira-valor-iframe/historico/8/2012
# 2012_8_carteira_valor.html
# salvando arquivo...
# https://www.valor.com.br/carteira-valor-iframe/historico/9/2012
# 2012_9_carteira_valor.html
# salvando arquivo...
# https://www.valor.com.br/carteira-valor-iframe/historico/10/2012
# 2012_10_carteira_valor.html
# salvando arquivo...
# https://www.valor.com.br/carteira-valor-iframe/historico/11/2012
# 2012_11_carteira_valor.html
# salvando arquivo...
# https://www.valor.com.br/carteira-valor-iframe/historico/12/2012
# 2012_12_carteira_valor.html
# salvando arquivo...
# https://www.valor.com.br/carteira-valor-iframe/historico/1/2013
# 2013_1_carteira_valor.html
# salvando arquivo...
# https://www.valor.com.br/carteira-valor-iframe/historico/2/2013
# 2013_2_carteira_valor.html
# salvando arquivo...
# https://www.valor.com.br/carteira-valor-iframe/historico/3/2013
# 2013_3_carteira_valor.html
# salvando arquivo...
# https://www.valor.com.br/carteira-valor-iframe/historico/4/2013
# 2013_4_carteira_valor.html
# salvando arquivo...
# https://www.valor.com.br/carteira-valor-iframe/historico/5/2013
# salvando arquivo...
# https://www.valor.com.br/carteira-valor-iframe/historico/4/2018
# 2018_4_carteira_valor.html
# salvando arquivo...
# https://www.valor.com.br/carteira-valor-iframe/historico/5/2018
# 2018_5_carteira_valor.html
# salvando arquivo...
# https://www.valor.com.br/carteira-valor-iframe/historico/6/2018
# 2018_6_carteira_valor.html
# salvando arquivo...
# https://www.valor.com.br/carteira-valor-iframe/historico/7/2018
# 2018_7_carteira_valor.html
# salvando arquivo...
# https://www.valor.com.br/carteira-valor-iframe/historico/8/2018
# 2018_8_carteira_valor.html
# salvando arquivo...
# https://www.valor.com.br/carteira-valor-iframe/historico/9/2018
# 2018_9_carteira_valor.html
# salvando arquivo...
# https://www.valor.com.br/carteira-valor-iframe/historico/10/2018
# 2018_10_carteira_valor.html
# salvando arquivo...
# https://www.valor.com.br/carteira-valor-iframe/historico/11/2018
# 2018_11_carteira_valor.html
# salvando arquivo...
# https://www.valor.com.br/carteira-valor-iframe/historico/12/2018
# 2018_12_carteira_valor.html
# salvando arquivo...
# https://www.valor.com.br/carteira-valor-iframe/historico/1/2019
# 2019_1_carteira_valor.html
# salvando arquivo...
# https://www.valor.com.br/carteira-valor-iframe/historico/2/2019
# 2019_2_carteira_valor.html
# salvando arquivo...
# https://www.valor.com.br/carteira-valor-iframe/historico/3/2019
# 2019_3_carteira_valor.html
# salvando arquivo...
# https://www.valor.com.br/carteira-valor-iframe/historico/4/2019
# 2019_4_carteira_valor.html
# salvando arquivo...
# https://www.valor.com.br/carteira-valor-iframe/historico/5/2019
# 2019_5_carteira_valor.html
# salvando arquivo...
# https://www.valor.com.br/carteira-valor-iframe/historico/6/2019
# 2019_6_carteira_valor.html
# salvando arquivo...
# https://www.valor.com.br/carteira-valor-iframe/historico/7/2019
# 2019_7_carteira_valor.html
# salvando arquivo...
# https://www.valor.com.br/carteira-valor-iframe/historico/8/2019
# 2019_8_carteira_valor.html
# salvando arquivo...
# https://www.valor.com.br/carteira-valor-iframe/historico/9/2019
# 2019_9_carteira_valor.html
# salvando arquivo...
# https://www.valor.com.br/carteira-valor-iframe/historico/10/2019
# 2019_10_carteira_valor.html
# salvando arquivo...
# https://www.valor.com.br/carteira-valor-iframe/historico/11/2019
# 2019_11_carteira_valor.html
# salvando arquivo...
# https://www.valor.com.br/carteira-valor-iframe/historico/12/2019
# 2019_12_carteira_valor.html
# salvando arquivo...
# https://www.valor.com.br/carteira-valor-iframe/historico/1/2020
# 2020_1_carteira_valor.html
# salvando arquivo...
# https://www.valor.com.br/carteira-valor-iframe/historico/2/2020
# 2020_2_carteira_valor.html
# salvando arquivo...
# https://www.valor.com.br/carteira-valor-iframe/historico/3/2020
# 2020_3_carteira_valor.html
# salvando arquivo...
# https://www.valor.com.br/carteira-valor-iframe/historico/4/2020
# 2020_4_carteira_valor.html
# salvando arquivo...
# https://www.valor.com.br/carteira-valor-iframe/historico/5/2020
# 2020_5_carteira_valor.html
# salvando arquivo...
# https://www.valor.com.br/carteira-valor-iframe/historico/6/2020
# 2020_6_carteira_valor.html
# salvando arquivo...
# https://www.valor.com.br/carteira-valor-iframe/historico/7/2020
# 2020_7_carteira_valor.html
# salvando arquivo...
# https://www.valor.com.br/carteira-valor-iframe/
# 2020_8_carteira_valor.html
# salvando arquivo...
